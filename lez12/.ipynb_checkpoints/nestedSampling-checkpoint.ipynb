# %%
import numpy as np
import scipy.stats
import pylab as plt
from matplotlib import pyplot as plt
from scipy import stats
from scipy.optimize import curve_fit
import random
import math

# %%
# !pip install emcee
import emcee

# !pip install corner
import corner

# !pip install dynesty
import dynesty
from dynesty import plotting as dyplot
from dynesty import utils as dyfunc
# Out:
# Requirement already satisfied: emcee in c:\users\giuli\anaconda3\lib\site-packages (3.1.6)
# Requirement already satisfied: numpy in c:\users\giuli\anaconda3\lib\site-packages (from emcee) (1.26.4)
# Requirement already satisfied: corner in c:\users\giuli\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: matplotlib>=2.1 in c:\users\giuli\anaconda3\lib\site-packages (from corner) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\giuli\anaconda3\lib\site-packages (from matplotlib>=2.1->corner) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\giuli\anaconda3\lib\site-packages (from matplotlib>=2.1->corner) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\giuli\anaconda3\lib\site-packages (from matplotlib>=2.1->corner) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\giuli\anaconda3\lib\site-packages (from matplotlib>=2.1->corner) (1.4.4)
# Requirement already satisfied: numpy>=1.23 in c:\users\giuli\anaconda3\lib\site-packages (from matplotlib>=2.1->corner) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\giuli\anaconda3\lib\site-packages (from matplotlib>=2.1->corner) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\giuli\anaconda3\lib\site-packages (from matplotlib>=2.1->corner) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\giuli\anaconda3\lib\site-packages (from matplotlib>=2.1->corner) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\giuli\anaconda3\lib\site-packages (from matplotlib>=2.1->corner) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\giuli\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.1->corner) (1.16.0)
# Requirement already satisfied: dynesty in c:\users\giuli\anaconda3\lib\site-packages (2.1.5)

# %% [markdown]
# First, we define the models and their respective likelihoods and priors.

# %%
# p = [b,A,t0,ln(alpha)]  parameters vector

def model_1(p,x):  #model for the burst
    array = np.full_like(x,1)
    array[x<p[2]] = p[0]
    array[x>=p[2]] = p[0]+p[1]*np.exp(-np.exp(p[3])*(x[x>=p[2]]-p[2]))
    return array

def log_likelihood_1(p,x,y,yerr):  #likelihood = prod(exp(-(y-model**2)/sigma**2)/(2*pi*sigma**2))
    return -0.5*np.sum((y-model_1(p,x))**2/yerr**2+np.log(2*np.pi*yerr**2))

def prior_1(p):
    prior_b = 50*p[0] #uniform distribution [0,50]
    prior_A = 50*p[1] #uniform distribution [0,50]
    prior_t0 = 100*p[2] #uniform distribution [0,100]
    prior_lnalpha = 5*(2*p[3]-1)  #ln(alpha) uniform distribution [-5,5]
    return [prior_b,prior_A,prior_t0,prior_lnalpha]

# p = [b,A,t0,ln(sigma)]  parameters vector

def model_2(p,x):
    return p[0]+p[1]*np.exp(-(x-p[2])**2/2/np.exp(p[3])**2)

def log_likelihood_2(p,x,y,yerr):  #likelihood = prod(exp(-(y-model**2)/sigma**2)/(2*pi*sigma**2))
    return -0.5*np.sum((y-model_2(p,x))**2/yerr**2+np.log(2*np.pi*yerr**2))

def prior_2(p):
    prior_b = 50*p[0] #uniform distribution [0,50]
    prior_A = 50*p[1] #uniform distribution [0,50]
    prior_t0 = 100*p[2] #uniform distribution [0,100]
    prior_lnsigma = 5*(2*p[3]-1)  #ln(sigma) uniform distribution [-5,5]
    return [prior_b,prior_A,prior_t0,prior_lnsigma]

# %% [markdown]
# Then we load and plot our data.

# %%
data = np.load('transient.npy')
plt.errorbar(data[:,0],data[:,1],data[:,2],fmt='.')
plt.xlabel('t')
plt.ylabel('flux')
plt.title('Data')
plt.show()

# %% [markdown]
# Now, we use nested sampling to estimate the four parameters. Then, we compute the median of each sample: these will be the estimated true values of the parameters that we will use to fit our data. We need to be carefull: the samples we obtain are weighted, therefore we need to reweight them first. We follow the same procedure for both models.

# %% [markdown]
# ## Model 1: burst

# %%
# "Static" nested sampling.
ndim = 4
sampler = dynesty.NestedSampler(log_likelihood_1, prior_1, ndim=ndim, logl_args=[data[:,0],data[:,1],data[:,2]])
sampler.run_nested()
sresults = sampler.results
# Out:
# 3938it [00:57,  6.38it/s, bound: 63 | nc: 329 | ncall: 64607 | eff(%):  6.095 | loglstar:   -inf < -178.455 <    inf | logz: -185.305 +/-  0.108 | dlogz: 36.724 >  0.509]   C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 3943it [01:04,  1.44it/s, bound: 70 | nc: 278 | ncall: 70193 | eff(%):  5.617 | loglstar:   -inf < -178.420 <    inf | logz: -185.302 +/-  0.108 | dlogz: 36.710 >  0.509] C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 3948it [01:07,  1.56it/s, bound: 73 | nc: 533 | ncall: 72157 | eff(%):  5.471 | loglstar:   -inf < -178.398 <    inf | logz: -185.298 +/-  0.108 | dlogz: 36.697 >  0.509] C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 3950it [01:11,  1.02s/it, bound: 76 | nc: 1986 | ncall: 74772 | eff(%):  5.283 | loglstar:   -inf < -178.394 <    inf | logz: -185.296 +/-  0.108 | dlogz: 36.691 >  0.509]C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 3958it [01:16,  1.91it/s, bound: 81 | nc: 260 | ncall: 78554 | eff(%):  5.039 | loglstar:   -inf < -178.350 <    inf | logz: -185.290 +/-  0.108 | dlogz: 36.669 >  0.509] C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 3959it [01:21,  1.30s/it, bound: 86 | nc: 3726 | ncall: 82280 | eff(%):  4.812 | loglstar:   -inf < -178.349 <    inf | logz: -185.290 +/-  0.108 | dlogz: 36.666 >  0.509]C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 7591it [02:08, 59.00it/s, +500 | bound: 144 | nc: 1 | ncall: 125789 | eff(%):  6.458 | loglstar:   -inf < -140.660 <    inf | logz: -155.053 +/-  0.167 | dlogz:  0.001 >  0.509]

# %%
rfig, raxes = dyplot.runplot(sresults)

# %%
labels = ['b','A',r"$t_0$",r"$ln(\alpha)$"]
tfig, taxes = dyplot.traceplot(sresults,labels=labels)
cfig, caxes = dyplot.cornerplot(sresults,show_titles=True, labels=labels)

# %%
weights = np.exp(sresults.logwt - sresults.logz[-1])
samples = sresults.samples
samples_equal = dyfunc.resample_equal(samples, weights) #Resample weighted samples

medians = np.median(samples_equal,0)
fig = corner.corner(samples_equal, levels=[0.9],labels=labels,
                    truths=medians,show_titles=True,quantiles=[0.16,0.5,0.84])

# %%
plt.errorbar(data[:,0],data[:,1],data[:,2],fmt='.',label='data')
plt.xlabel('t')
plt.ylabel('flux')
plt.title('First model')
plt.plot(data[:,0], model_1(medians,data[:,0]),label='fit')
plt.legend()
plt.show()

# %% [markdown]
# ## Model 2: gaussian profile

# %%
ndim = 4

# "Static" nested sampling.
sampler2 = dynesty.NestedSampler(log_likelihood_2, prior_2, ndim=ndim, logl_args=[data[:,0],data[:,1],data[:,2]])
sampler2.run_nested()
sresults2 = sampler2.results
# Out:
# 4530it [01:29, 18.08it/s, bound: 95 | nc: 99 | ncall: 88823 | eff(%):  5.100 | loglstar:   -inf < -172.042 <    inf | logz: -182.713 +/-  0.134 | dlogz: 25.992 >  0.509]    C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 4568it [01:32, 17.25it/s, bound: 99 | nc: 72 | ncall: 91660 | eff(%):  4.984 | loglstar:   -inf < -171.522 <    inf | logz: -182.318 +/-  0.136 | dlogz: 25.521 >  0.509] C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 4685it [01:38, 34.93it/s, bound: 106 | nc: 31 | ncall: 97088 | eff(%):  4.826 | loglstar:   -inf < -170.240 <    inf | logz: -181.121 +/-  0.139 | dlogz: 24.089 >  0.509] C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 4747it [01:41, 39.80it/s, bound: 109 | nc: 93 | ncall: 99435 | eff(%):  4.774 | loglstar:   -inf < -169.639 <    inf | logz: -180.557 +/-  0.140 | dlogz: 23.401 >  0.509] C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 4815it [01:49, 12.78it/s, bound: 118 | nc: 243 | ncall: 106032 | eff(%):  4.541 | loglstar:   -inf < -168.868 <    inf | logz: -179.980 +/-  0.141 | dlogz: 22.688 >  0.509]C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 4866it [01:51, 37.52it/s, bound: 120 | nc: 19 | ncall: 107649 | eff(%):  4.520 | loglstar:   -inf < -168.357 <    inf | logz: -179.545 +/-  0.141 | dlogz: 23.773 >  0.509] C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 4890it [01:56,  9.95it/s, bound: 127 | nc: 33 | ncall: 112842 | eff(%):  4.333 | loglstar:   -inf < -168.198 <    inf | logz: -179.348 +/-  0.141 | dlogz: 23.527 >  0.509]C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 4899it [02:13,  1.56it/s, bound: 146 | nc: 14020 | ncall: 126983 | eff(%):  3.858 | loglstar:   -inf < -168.102 <    inf | logz: -179.277 +/-  0.141 | dlogz: 23.438 >  0.509]C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 4900it [02:15,  1.40it/s, bound: 149 | nc: 1821 | ncall: 128804 | eff(%):  3.804 | loglstar:   -inf < -168.090 <    inf | logz: -179.269 +/-  0.141 | dlogz: 23.428 >  0.509] C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 4978it [02:24, 32.21it/s, bound: 158 | nc: 24 | ncall: 136086 | eff(%):  3.658 | loglstar:   -inf < -167.318 <    inf | logz: -178.640 +/-  0.142 | dlogz: 22.643 >  0.509]  C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 4990it [02:37,  3.36it/s, bound: 174 | nc: 132 | ncall: 148078 | eff(%):  3.370 | loglstar:   -inf < -167.183 <    inf | logz: -178.545 +/-  0.142 | dlogz: 22.524 >  0.509]C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 4991it [02:40,  2.54it/s, bound: 178 | nc: 2516 | ncall: 150594 | eff(%):  3.314 | loglstar:   -inf < -167.182 <    inf | logz: -178.537 +/-  0.142 | dlogz: 22.514 >  0.509]C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 5072it [02:55,  3.91it/s, bound: 197 | nc: 87 | ncall: 164886 | eff(%):  3.076 | loglstar:   -inf < -166.400 <    inf | logz: -177.898 +/-  0.143 | dlogz: 21.714 >  0.509]  C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 5075it [02:58,  2.30it/s, bound: 201 | nc: 129 | ncall: 168115 | eff(%):  3.019 | loglstar:   -inf < -166.372 <    inf | logz: -177.875 +/-  0.143 | dlogz: 21.684 >  0.509]C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 5083it [03:03,  2.03it/s, bound: 207 | nc: 706 | ncall: 172746 | eff(%):  2.942 | loglstar:   -inf < -166.305 <    inf | logz: -177.813 +/-  0.143 | dlogz: 21.606 >  0.509] C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 5085it [03:06,  1.38it/s, bound: 210 | nc: 2061 | ncall: 174859 | eff(%):  2.908 | loglstar:   -inf < -166.289 <    inf | logz: -177.798 +/-  0.144 | dlogz: 21.587 >  0.509]C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 5086it [03:12,  1.54s/it, bound: 217 | nc: 5040 | ncall: 179899 | eff(%):  2.827 | loglstar:   -inf < -166.287 <    inf | logz: -177.790 +/-  0.144 | dlogz: 21.577 >  0.509]C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 5087it [03:18,  2.29s/it, bound: 223 | nc: 4383 | ncall: 184282 | eff(%):  2.760 | loglstar:   -inf < -166.284 <    inf | logz: -177.782 +/-  0.144 | dlogz: 21.567 >  0.509]C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 5089it [03:20,  1.88s/it, bound: 226 | nc: 747 | ncall: 187126 | eff(%):  2.720 | loglstar:   -inf < -166.250 <    inf | logz: -177.767 +/-  0.144 | dlogz: 21.548 >  0.509] C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 5091it [03:27,  2.27s/it, bound: 233 | nc: 785 | ncall: 192008 | eff(%):  2.651 | loglstar:   -inf < -166.234 <    inf | logz: -177.752 +/-  0.144 | dlogz: 21.529 >  0.509] C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 5092it [03:30,  2.60s/it, bound: 236 | nc: 2358 | ncall: 194366 | eff(%):  2.620 | loglstar:   -inf < -166.228 <    inf | logz: -177.744 +/-  0.144 | dlogz: 21.519 >  0.509]C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 5093it [03:32,  2.37s/it, bound: 238 | nc: 1382 | ncall: 195748 | eff(%):  2.602 | loglstar:   -inf < -166.189 <    inf | logz: -177.736 +/-  0.144 | dlogz: 21.509 >  0.509]C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 5095it [03:40,  3.03s/it, bound: 246 | nc: 6237 | ncall: 202002 | eff(%):  2.522 | loglstar:   -inf < -166.175 <    inf | logz: -177.721 +/-  0.144 | dlogz: 21.490 >  0.509]C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 8497it [03:56, 35.93it/s, +500 | bound: 267 | nc: 1 | ncall: 218077 | eff(%):  4.135 | loglstar:   -inf < -144.361 <    inf | logz: -160.619 +/-  0.180 | dlogz:  0.001 >  0.509]

# %%
rfig, raxes = dyplot.runplot(sresults2)

# %%
labels = ['b','A',r"$t_0$",r"$ln(\sigma)$"]
tfig, taxes = dyplot.traceplot(sresults2, labels=labels)
cfig, caxes = dyplot.cornerplot(sresults2, show_titles=True, labels=labels)

# %%
 #Resample weighted samples
weights2 = np.exp(sresults2.logwt - sresults2.logz[-1])
samples2 = sresults2.samples
samples_equal2 = dyfunc.resample_equal(samples2, weights2)

medians2 = np.median(samples_equal2,0)
fig = corner.corner(samples_equal2, levels=[0.9],labels=labels,
                    truths=medians2,show_titles=True,quantiles=[0.16,0.5,0.84])

# %%
plt.errorbar(data[:,0],data[:,1],data[:,2],fmt='.',label='data')
plt.xlabel('t')
plt.ylabel('flux')
plt.title('Second model')
plt.plot(data[:,0], model_2(medians2,data[:,0]),label='fit')
plt.legend()
plt.show()

# %% [markdown]
# ## Model comparison

# %% [markdown]
# Now we want to compare the two models: in order to do this, we compute Bayes' factor $B_{21}$, which is given by the ratio between the evidence of the second model and the evidence of the first model. We only need to compute $B_{21}$ to compare the two models since we took the same priors for both models. \
# We use Jeffrey's scale to decide which model si preferred.

# %%
b = np.exp(sresults.logz[-1])/np.exp(sresults2.logz[-1])
print('Bayes factor = ', b)
if b>100:
    print('The first model is highly preferred')
# Out:
# Bayes factor =  261.3918773817882
# The first model is highly preferred
