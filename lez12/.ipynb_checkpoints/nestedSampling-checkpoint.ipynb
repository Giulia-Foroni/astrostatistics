# %%
import numpy as np
import scipy.stats
import pylab as plt
from matplotlib import pyplot as plt
from scipy import stats
from scipy.optimize import curve_fit
import random
import math

# %%
# !pip install emcee
import emcee

# !pip install corner
import corner

# !pip install dynesty
import dynesty
from dynesty import plotting as dyplot
from dynesty import utils as dyfunc
# Out:
# Requirement already satisfied: emcee in c:\users\giuli\anaconda3\lib\site-packages (3.1.6)
# Requirement already satisfied: numpy in c:\users\giuli\anaconda3\lib\site-packages (from emcee) (1.26.4)
# Requirement already satisfied: corner in c:\users\giuli\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: matplotlib>=2.1 in c:\users\giuli\anaconda3\lib\site-packages (from corner) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\giuli\anaconda3\lib\site-packages (from matplotlib>=2.1->corner) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\giuli\anaconda3\lib\site-packages (from matplotlib>=2.1->corner) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\giuli\anaconda3\lib\site-packages (from matplotlib>=2.1->corner) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\giuli\anaconda3\lib\site-packages (from matplotlib>=2.1->corner) (1.4.4)
# Requirement already satisfied: numpy>=1.23 in c:\users\giuli\anaconda3\lib\site-packages (from matplotlib>=2.1->corner) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\giuli\anaconda3\lib\site-packages (from matplotlib>=2.1->corner) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\giuli\anaconda3\lib\site-packages (from matplotlib>=2.1->corner) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\giuli\anaconda3\lib\site-packages (from matplotlib>=2.1->corner) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\giuli\anaconda3\lib\site-packages (from matplotlib>=2.1->corner) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\giuli\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.1->corner) (1.16.0)
# Requirement already satisfied: dynesty in c:\users\giuli\anaconda3\lib\site-packages (2.1.5)

# %%
# p = [b,A,t0,ln(alpha)]  parameters vector

def model_1(p,x):  #model for the burst
    array = np.full_like(x,1)
    array[x<p[2]] = p[0]
    array[x>=p[2]] = p[0]+p[1]*np.exp(-np.exp(p[3])*(x[x>=p[2]]-p[2]))
    return array

def log_likelihood_1(p,x,y,yerr):  #likelihood = prod(exp(-(y-model**2)/sigma**2)/(2*pi*sigma**2))
    return -0.5*np.sum((y-model_1(p,x))**2/yerr**2+np.log(2*np.pi*yerr**2))

def prior_1(p):
    prior_b = 50*p[0] #uniform distribution [0,50]
    prior_A = 50*p[1] #uniform distribution [0,50]
    prior_t0 = 100*p[2] #uniform distribution [0,100]
    prior_lnalpha = 5*(2*p[3]-1)  #ln(alpha) uniform distribution [-5,5]
    return [prior_b,prior_A,prior_t0,prior_lnalpha]

# p = [b,A,t0,ln(sigma)]  parameters vector

def model_2(p,x):
    return p[0]+p[1]*np.exp(-(x-p[2])**2/2/np.exp(p[3])**2)

def log_likelihood_2(p,x,y,yerr):  #likelihood = prod(exp(-(y-model**2)/sigma**2)/(2*pi*sigma**2))
    return -0.5*np.sum((y-model_2(p,x))**2/yerr**2+np.log(2*np.pi*yerr**2))

def prior_2(p):
    prior_b = 50*p[0] #uniform distribution [0,50]
    prior_A = 50*p[1] #uniform distribution [0,50]
    prior_t0 = 100*p[2] #uniform distribution [0,100]
    prior_lnsigma = 5*(2*p[3]-1)  #ln(sigma) uniform distribution [-5,5]
    return [prior_b,prior_A,prior_t0,prior_lnsigma]

# %%
data = np.load('transient.npy')
plt.errorbar(data[:,0],data[:,1],data[:,2],fmt='.')
plt.xlabel('t')
plt.ylabel('flux')
plt.title('Data')
plt.show()

# %%
# "Static" nested sampling.
ndim = 4
sampler = dynesty.NestedSampler(log_likelihood_1, prior_1, ndim=ndim, logl_args=[data[:,0],data[:,1],data[:,2]])
sampler.run_nested()
sresults = sampler.results
# Out:
# 3792it [01:13, 22.14it/s, bound: 73 | nc: 62 | ncall: 71665 | eff(%):  5.291 | loglstar:   -inf < -178.817 <    inf | logz: -185.120 +/-  0.106 | dlogz: 34.095 >  0.509]    C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 3797it [01:13, 15.23it/s, bound: 74 | nc: 185 | ncall: 71880 | eff(%):  5.282 | loglstar:   -inf < -178.806 <    inf | logz: -185.117 +/-  0.106 | dlogz: 34.082 >  0.509]C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 3812it [01:17,  5.31it/s, bound: 77 | nc: 452 | ncall: 74374 | eff(%):  5.125 | loglstar:   -inf < -178.729 <    inf | logz: -185.108 +/-  0.106 | dlogz: 34.043 >  0.509]C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 3818it [01:20,  3.64it/s, bound: 79 | nc: 79 | ncall: 76116 | eff(%):  5.016 | loglstar:   -inf < -178.671 <    inf | logz: -185.105 +/-  0.106 | dlogz: 34.028 >  0.509] C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 3833it [01:22,  9.14it/s, bound: 81 | nc: 178 | ncall: 77658 | eff(%):  4.936 | loglstar:   -inf < -178.559 <    inf | logz: -185.095 +/-  0.106 | dlogz: 33.989 >  0.509]C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 3835it [01:23,  4.50it/s, bound: 82 | nc: 338 | ncall: 78357 | eff(%):  4.894 | loglstar:   -inf < -178.542 <    inf | logz: -185.094 +/-  0.106 | dlogz: 33.983 >  0.509]C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 3837it [01:26,  2.32it/s, bound: 84 | nc: 954 | ncall: 79357 | eff(%):  4.835 | loglstar:   -inf < -178.501 <    inf | logz: -185.093 +/-  0.106 | dlogz: 33.978 >  0.509]C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 3840it [01:27,  1.99it/s, bound: 85 | nc: 606 | ncall: 80647 | eff(%):  4.761 | loglstar:   -inf < -178.471 <    inf | logz: -185.090 +/-  0.106 | dlogz: 33.970 >  0.509]C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 3843it [01:29,  2.34it/s, bound: 86 | nc: 176 | ncall: 81287 | eff(%):  4.728 | loglstar:   -inf < -178.459 <    inf | logz: -185.088 +/-  0.106 | dlogz: 33.962 >  0.509]C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 3846it [01:30,  2.41it/s, bound: 87 | nc: 280 | ncall: 82108 | eff(%):  4.684 | loglstar:   -inf < -178.435 <    inf | logz: -185.086 +/-  0.106 | dlogz: 33.954 >  0.509]C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 3848it [01:31,  2.12it/s, bound: 88 | nc: 137 | ncall: 82801 | eff(%):  4.647 | loglstar:   -inf < -178.421 <    inf | logz: -185.085 +/-  0.106 | dlogz: 33.948 >  0.509]C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 3850it [01:33,  1.81it/s, bound: 89 | nc: 540 | ncall: 83578 | eff(%):  4.606 | loglstar:   -inf < -178.391 <    inf | logz: -185.083 +/-  0.106 | dlogz: 33.943 >  0.509]C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 3851it [01:34,  1.40it/s, bound: 90 | nc: 459 | ncall: 84037 | eff(%):  4.583 | loglstar:   -inf < -178.376 <    inf | logz: -185.083 +/-  0.106 | dlogz: 33.940 >  0.509]C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 3853it [01:35,  1.31it/s, bound: 91 | nc: 900 | ncall: 84985 | eff(%):  4.534 | loglstar:   -inf < -178.356 <    inf | logz: -185.081 +/-  0.106 | dlogz: 33.935 >  0.509]C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 3854it [01:38,  1.13s/it, bound: 93 | nc: 1233 | ncall: 86218 | eff(%):  4.470 | loglstar:   -inf < -178.353 <    inf | logz: -185.080 +/-  0.106 | dlogz: 33.932 >  0.509]C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 7627it [02:26, 51.90it/s, +500 | bound: 152 | nc: 1 | ncall: 131289 | eff(%):  6.214 | loglstar:   -inf < -140.659 <    inf | logz: -155.122 +/-  0.167 | dlogz:  0.001 >  0.509]

# %%
rfig, raxes = dyplot.runplot(sresults)

# %%
labels = ['b','A','t0','ln(sigma)']
tfig, taxes = dyplot.traceplot(sresults,labels=labels)
cfig, caxes = dyplot.cornerplot(sresults,show_titles=True, labels=labels)

# %%
weights = np.exp(sresults.logwt - sresults.logz[-1])
samples = sresults.samples
samples_equal = dyfunc.resample_equal(samples, weights) #Resample weighted samples
medians = np.median(samples_equal,0)
plt.errorbar(data[:,0],data[:,1],data[:,2],fmt='.',label='data')
plt.xlabel('t')
plt.ylabel('flux')
plt.title('First model')
plt.plot(data[:,0], model_1(medians,data[:,0]),label='fit')
plt.legend()
plt.show()

# %%
ndim = 4

# "Static" nested sampling.
sampler2 = dynesty.NestedSampler(log_likelihood_2, prior_2, ndim=ndim, logl_args=[data[:,0],data[:,1],data[:,2]])
sampler2.run_nested()
sresults2 = sampler2.results
# Out:
# 1986it [00:09, 47.64it/s, bound: 5 | nc: 29 | ncall: 21859 | eff(%):  9.086 | loglstar:   -inf < -250.882 <    inf | logz: -259.443 +/-  0.126 | dlogz: 83.692 >  0.509]      C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 4073it [00:59,  8.60it/s, bound: 61 | nc: 74 | ncall: 63496 | eff(%):  6.415 | loglstar:   -inf < -178.234 <    inf | logz: -185.493 +/-  0.110 | dlogz: 28.828 >  0.509] C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 4075it [01:00,  4.24it/s, bound: 62 | nc: 487 | ncall: 64569 | eff(%):  6.311 | loglstar:   -inf < -178.215 <    inf | logz: -185.491 +/-  0.110 | dlogz: 28.823 >  0.509]C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 4077it [01:01,  3.72it/s, bound: 63 | nc: 240 | ncall: 64894 | eff(%):  6.283 | loglstar:   -inf < -178.206 <    inf | logz: -185.489 +/-  0.110 | dlogz: 28.817 >  0.509]C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 4080it [01:03,  2.90it/s, bound: 64 | nc: 350 | ncall: 66006 | eff(%):  6.181 | loglstar:   -inf < -178.148 <    inf | logz: -185.487 +/-  0.110 | dlogz: 28.808 >  0.509]C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 4460it [01:16, 72.19it/s, bound: 81 | nc: 62 | ncall: 78786 | eff(%):  5.661 | loglstar:   -inf < -174.145 <    inf | logz: -184.213 +/-  0.125 | dlogz: 28.253 >  0.509] C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 5016it [01:32, 66.09it/s, bound: 102 | nc: 37 | ncall: 94493 | eff(%):  5.308 | loglstar:   -inf < -168.715 <    inf | logz: -180.041 +/-  0.142 | dlogz: 22.971 >  0.509]C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 5155it [01:38, 22.13it/s, bound: 110 | nc: 227 | ncall: 100477 | eff(%):  5.131 | loglstar:   -inf < -167.511 <    inf | logz: -179.028 +/-  0.144 | dlogz: 21.680 >  0.509]C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 5184it [01:49,  3.91it/s, bound: 128 | nc: 478 | ncall: 113868 | eff(%):  4.553 | loglstar:   -inf < -167.189 <    inf | logz: -178.828 +/-  0.144 | dlogz: 21.422 >  0.509] C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 5185it [01:52,  1.82it/s, bound: 132 | nc: 2593 | ncall: 116461 | eff(%):  4.452 | loglstar:   -inf < -167.186 <    inf | logz: -178.821 +/-  0.144 | dlogz: 21.413 >  0.509]C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 5215it [01:57,  7.48it/s, bound: 139 | nc: 179 | ncall: 122282 | eff(%):  4.265 | loglstar:   -inf < -166.929 <    inf | logz: -178.609 +/-  0.144 | dlogz: 21.141 >  0.509] C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 5219it [01:59,  5.09it/s, bound: 141 | nc: 911 | ncall: 123303 | eff(%):  4.233 | loglstar:   -inf < -166.899 <    inf | logz: -178.581 +/-  0.144 | dlogz: 21.105 >  0.509]C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 5221it [02:03,  1.86it/s, bound: 146 | nc: 1234 | ncall: 127144 | eff(%):  4.106 | loglstar:   -inf < -166.876 <    inf | logz: -178.567 +/-  0.144 | dlogz: 21.087 >  0.509]C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 5223it [02:09,  1.09s/it, bound: 154 | nc: 1480 | ncall: 133322 | eff(%):  3.918 | loglstar:   -inf < -166.845 <    inf | logz: -178.552 +/-  0.144 | dlogz: 21.069 >  0.509]C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 5224it [02:14,  1.58s/it, bound: 160 | nc: 4472 | ncall: 137794 | eff(%):  3.791 | loglstar:   -inf < -166.840 <    inf | logz: -178.545 +/-  0.144 | dlogz: 21.059 >  0.509]C:\Users\giuli\anaconda3\Lib\site-packages\dynesty\bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 8638it [02:27, 58.62it/s, +500 | bound: 177 | nc: 1 | ncall: 150951 | eff(%):  6.074 | loglstar:   -inf < -144.324 <    inf | logz: -160.864 +/-  0.181 | dlogz:  0.001 >  0.509]

# %%
rfig, raxes = dyplot.runplot(sresults2)

# %%
tfig, taxes = dyplot.traceplot(sresults2, labels=labels)
cfig, caxes = dyplot.cornerplot(sresults2, show_titles=True, labels=labels)

# %%
weights2 = np.exp(sresults2.logwt - sresults2.logz[-1])
samples2 = sresults2.samples
samples_equal2 = dyfunc.resample_equal(samples2, weights2) #Resample weighted samples
medians2 = np.median(samples_equal2,0)
plt.errorbar(data[:,0],data[:,1],data[:,2],fmt='.',label='data')
plt.xlabel('t')
plt.ylabel('flux')
plt.title('Second model')
plt.plot(data[:,0], model_2(medians2,data[:,0]),label='fit')
plt.legend()
plt.show()

# %%
b = np.exp(sresults2.logz[-1])/np.exp(sresults.logz[-1])
print('Bayes factor = ', b)
if b<1:
    print('The first model is preferred')
else:
    print('The second model is preferred')
# Out:
# Bayes factor =  0.003206001189614135
# The first model is preferred
