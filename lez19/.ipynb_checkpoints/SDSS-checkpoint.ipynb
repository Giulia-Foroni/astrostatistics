# %%
import sklearn
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn import metrics
from astroML.utils import completeness_contamination
from sklearn.metrics import roc_curve

from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis as QDA
from astroML.classification import GMMBayes
from sklearn.neighbors import KNeighborsClassifier

import pandas as pd
import numpy as np
import scipy.stats
import pylab as plt
from matplotlib import pyplot as plt
from scipy import stats
import random
import math
import seaborn as sns

# %% [markdown]
# We want to classify galaxies vs quasars in the Sloan Digital Sky Survey. In our dataset we have the intensity of the radiation in each color band.

# %%
import pandas as pd
data = pd.read_csv("galaxyquasar.csv")
data
# Out:
#               u         g         r         i         z   class        z1  \
# 0      18.97213  18.53676  18.58280  18.34936  18.29215     QSO  0.522819
# 1      19.24592  17.47646  16.47817  16.04472  15.68851  GALAXY  0.122846
# 2      19.43536  17.70268  16.91565  16.58327  16.39128  GALAXY  0.000000
# 3      19.31626  18.18312  17.39591  16.94549  16.65395  GALAXY  0.147435
# 4      19.28828  19.11188  18.88937  18.80013  18.49183     QSO  2.011455
# ...         ...       ...       ...       ...       ...     ...       ...
# 49995  19.37295  18.12382  17.39886  16.98503  16.70585  GALAXY  0.113016
# 49996  18.52021  16.88262  16.03280  15.56884  15.22454  GALAXY  0.085063
# 49997  18.62718  17.30876  16.87371  16.62399  16.42296  GALAXY  0.054429
# 49998  19.55140  18.27711  17.62101  17.21947  17.03347  GALAXY  0.112571
# 49999  18.80772  17.75751  17.40500  17.21650  17.12295  GALAXY  0.043652
#
#            zerr
# 0      0.000155
# 1      0.000028
# 2      0.000000
# 3      0.000009
# 4      0.000631
# ...         ...
# 49995  0.000011
# 49996  0.000014
# 49997  0.000008
# 49998  0.000009
# 49999  0.000007
#
# [50000 rows x 8 columns]

# %%
print('Fraction of quasars: '+str(len(data['class'][data['class'] == 'QSO'])/len(data['class'])))
print('Fraction of galaxies: '+str(len(data['class'][data['class'] == 'GALAXY'])/len(data['class'])))
# Out:
# Fraction of quasars: 0.14268
# Fraction of galaxies: 0.85732

# %% [markdown]
# Only $14\%$ of the samples is a quasar. We want to be sure to correctly identify all (or most) of them: therefore, we want to maximise the completeness, at the cost of a slightly higher contamination.

# %% [markdown]
# First, we split our data in training and test set. Then, we create arrays for the $(u-g)$, $(g-r)$, $(r-i)$ and $(i-z)$ colors. We also create an array with the class labels where $galaxy=0$ and $quasar=1$.

# %%
X_train, X_test = train_test_split(data,train_size=0.8)

# %%
u_g_train = (X_train['u']-X_train['g']).to_numpy()
g_r_train = (X_train['g']-X_train['r']).to_numpy()
r_i_train = (X_train['r']-X_train['i']).to_numpy()
i_z_train = (X_train['i']-X_train['z']).to_numpy()
classes_train = (X_train['class']).to_numpy()
classes_train[classes_train == 'QSO'] = 1
classes_train[classes_train == 'GALAXY'] = 0
classes_train = np.float64(classes_train)

u_g_test = (X_test['u']-X_test['g']).to_numpy()
g_r_test = (X_test['g']-X_test['r']).to_numpy()
r_i_test = (X_test['r']-X_test['i']).to_numpy()
i_z_test = (X_test['i']-X_test['z']).to_numpy()
classes_test = (X_test['class']).to_numpy()
classes_test[classes_test == 'QSO'] = 1
classes_test[classes_test == 'GALAXY'] = 0
classes_test = np.float64(classes_test)

# %%
matrix_train = np.column_stack((u_g_train,g_r_train,r_i_train,i_z_train))
matrix_test = np.column_stack((u_g_test,g_r_test,r_i_test,i_z_test))

# %% [markdown]
# # Gaussian Naive Bayes

# %% [markdown]
# Let's compute the completeness and the contamination as a function of the number of features that we use to train the algorithm.

# %%
gnb = GaussianNB()

completeness = []
contamination = []

for i in range(matrix_train.shape[1]):
    gnb.fit(matrix_train[:,:i+1],classes_train)
    predicted_labels_gnb = gnb.predict(matrix_test[:,:i+1])
    completeness.append(completeness_contamination(predicted_labels_gnb, classes_test)[0])
    contamination.append(completeness_contamination(predicted_labels_gnb, classes_test)[1])

# %%
x = [1,2,3,4]
fig, axes = plt.subplots(2,1)
fig.subplots_adjust(hspace=0.6)

axes[0].plot(x,completeness)
axes[0].set_title('completeness')
axes[0].set_ylabel('completeness')
axes[0].set_xticks(x)

axes[1].plot(x,contamination)
axes[1].set_title('contamination')
axes[1].set_ylabel('contamination')
axes[1].set_xlabel('Number of features')
axes[1].set_xticks(x)

plt.show()

# %% [markdown]
# Using only the first two components gives us the highest completeness.

# %%
sns.scatterplot(x=data['u']-data['g'],y=data['g']-data['r'],hue=data['class'])

# predict the classification probabilities on a grid
gnb = GaussianNB()
gnb.fit(matrix_train[:,:2],classes_train)
xlim = (-2, 6)
ylim = (-11, 5)
xx, yy = np.meshgrid(np.linspace(xlim[0], xlim[1], 71),
                     np.linspace(ylim[0], ylim[1], 81))
Z = gnb.predict_proba(np.c_[xx.ravel(), yy.ravel()])
Z = Z[:, 1].reshape(xx.shape)
plt.contour(xx, yy, Z, [0.5], colors='k')

plt.xlabel('u-g')
plt.ylabel('g-r')
plt.title('Dataset')
plt.show()

# %% [markdown]
# # Linear discriminant analysis

# %%
lda = LDA()

completeness = []
contamination = []

for i in range(matrix_train.shape[1]):
    lda.fit(matrix_train[:,:i+1],classes_train)
    predicted_labels_lda = lda.predict(matrix_test[:,:i+1])
    completeness.append(completeness_contamination(predicted_labels_lda, classes_test)[0])
    contamination.append(completeness_contamination(predicted_labels_lda, classes_test)[1])

# %%
x = [1,2,3,4]
fig, axes = plt.subplots(2,1)
fig.subplots_adjust(hspace=0.6)

axes[0].plot(x,completeness)
axes[0].set_title('completeness')
axes[0].set_ylabel('completeness')
axes[0].set_xticks(x)

axes[1].plot(x,contamination)
axes[1].set_title('contamination')
axes[1].set_ylabel('contamination')
axes[1].set_xlabel('Number of features')
axes[1].set_xticks(x)

plt.show()

# %%
sns.scatterplot(x=data['u']-data['g'],y=data['g']-data['r'],hue=data['class'])

# predict the classification probabilities on a grid
lda = LDA()
lda.fit(matrix_train[:,:2],classes_train)
xlim = (-2, 6)
ylim = (-11, 5)
xx, yy = np.meshgrid(np.linspace(xlim[0], xlim[1], 71),
                     np.linspace(ylim[0], ylim[1], 81))
Z = lda.predict_proba(np.c_[xx.ravel(), yy.ravel()])
Z = Z[:, 1].reshape(xx.shape)
plt.contour(xx, yy, Z, [0.5], colors='k')

plt.xlabel('u-g')
plt.ylabel('g-r')
plt.title('Dataset')
plt.show()

# %% [markdown]
# # Quadratic disciminant analysis

# %%
qda = QDA()

completeness = []
contamination = []

for i in range(matrix_train.shape[1]):
    qda.fit(matrix_train[:,:i+1],classes_train)
    predicted_labels_qda = qda.predict(matrix_test[:,:i+1])
    completeness.append(completeness_contamination(predicted_labels_qda, classes_test)[0])
    contamination.append(completeness_contamination(predicted_labels_qda, classes_test)[1])

# %%
x = [1,2,3,4]
fig, axes = plt.subplots(2,1)
fig.subplots_adjust(hspace=0.6)

axes[0].plot(x,completeness)
axes[0].set_title('completeness')
axes[0].set_ylabel('completeness')
axes[0].set_xticks(x)

axes[1].plot(x,contamination)
axes[1].set_title('contamination')
axes[1].set_ylabel('contamination')
axes[1].set_xlabel('Number of features')
axes[1].set_xticks(x)

plt.show()

# %%
sns.scatterplot(x=data['u']-data['g'],y=data['g']-data['r'],hue=data['class'])

# predict the classification probabilities on a grid
qda = QDA()
qda.fit(matrix_train[:,:2],classes_train)
xlim = (-2, 6)
ylim = (-11, 5)
xx, yy = np.meshgrid(np.linspace(xlim[0], xlim[1], 81),
                     np.linspace(ylim[0], ylim[1], 81))
Z = qda.predict_proba(np.c_[xx.ravel(), yy.ravel()])
Z = Z[:, 1].reshape(xx.shape)
plt.contour(xx, yy, Z, [0.5], colors='k')

plt.xlabel('u-g')
plt.ylabel('g-r')
plt.title('Dataset')
plt.show()

# %% [markdown]
# # GMM Bayes

# %%
n_components = np.linspace(1,20,20,dtype = int)
model = GMMBayes()
grid = GridSearchCV(model, {'n_components': n_components}, scoring = 'accuracy', cv= 5) 
grid.fit(matrix_train,classes_train)
print('Best iperparameter: ', grid.best_params_)
print('Best score: ', grid.best_score_)
# Out:
# Best iperparameter:  {'n_components': 20}
# Best score:  0.9853500000000001

# %%
completeness = []
contamination = []

for j in [2,5,10]:
    gmmb = GMMBayes(j)
    for i in range(matrix_train.shape[1]):
        gmmb.fit(matrix_train[:,:i+1],classes_train)
        predicted_labels_gmmb = gmmb.predict(matrix_test[:,:i+1])
        completeness.append(completeness_contamination(predicted_labels_gmmb, classes_test)[0])
        contamination.append(completeness_contamination(predicted_labels_gmmb, classes_test)[1])

# %%
x = [1,2,3,4]
fig, axes = plt.subplots(2,1)
fig.subplots_adjust(hspace=0.6)

axes[0].plot(x,completeness[:4],label='n = 2')
axes[0].plot(x,completeness[4:8],label='n = 5')
axes[0].plot(x,completeness[8:12],label='n = 10')
axes[0].set_title('completeness')
axes[0].set_ylabel('completeness')
axes[0].set_xticks(x)
axes[0].legend()

axes[1].plot(x,contamination[:4],label='n = 2')
axes[1].plot(x,contamination[4:8],label='n = 5')
axes[1].plot(x,contamination[8:12],label='n = 10')
axes[1].set_title('contamination')
axes[1].set_ylabel('contamination')
axes[1].set_xlabel('Number of features')
axes[1].set_xticks(x)
axes[1].legend()

plt.show()

# %%
sns.scatterplot(x=data['u']-data['g'],y=data['g']-data['r'],hue=data['class'])

# predict the classification probabilities on a grid
gmmb = GMMBayes(5) # 2 classes
gmmb.fit(matrix_train[:,:2],classes_train)
xlim = (-2, 6)
ylim = (-11, 5)
xx, yy = np.meshgrid(np.linspace(xlim[0], xlim[1], 71),
                         np.linspace(ylim[0], ylim[1], 81))
Z = gmmb.predict_proba(np.c_[xx.ravel(), yy.ravel()])
Z = Z[:, 1].reshape(xx.shape)
plt.contour(xx, yy, Z, [0.5], colors='k')

plt.xlabel('u-g')
plt.ylabel('g-r')
plt.title('Dataset')
plt.show()

# %% [markdown]
# # K-Nearest neighbors

# %%
neighbors = np.linspace(1,20,20,dtype = int)
model = KNeighborsClassifier()
grid = GridSearchCV(model, {'n_neighbors': neighbors}, scoring = 'accuracy', cv= 5) 
grid.fit(matrix_train,classes_train)
print('Best iperparameter: ', grid.best_params_)
print('Best score: ', grid.best_score_)
# Out:
# Best iperparameter:  {'n_neighbors': 16}
# Best score:  0.9857750000000001

# %%
completeness = []
contamination = []

for j in [10,25,50]:
    knc = KNeighborsClassifier(j)
    for i in range(matrix_train.shape[1]):
        knc.fit(matrix_train[:,:i+1],classes_train)
        predicted_labels_knc = knc.predict(matrix_test[:,:i+1])
        completeness.append(completeness_contamination(predicted_labels_knc, classes_test)[0])
        contamination.append(completeness_contamination(predicted_labels_knc, classes_test)[1])

# %%
x = [1,2,3,4]
fig, axes = plt.subplots(2,1)
fig.subplots_adjust(hspace=0.6)

axes[0].plot(x,completeness[:4],label='n = 10')
axes[0].plot(x,completeness[4:8],label='n = 25')
axes[0].plot(x,completeness[8:12],label='n = 50')
axes[0].set_title('completeness')
axes[0].set_ylabel('completeness')
axes[0].set_xticks(x)
axes[0].legend()

axes[1].plot(x,contamination[:4],label='n = 10')
axes[1].plot(x,contamination[4:8],label='n = 25')
axes[1].plot(x,contamination[8:12],label='n = 50')
axes[1].set_title('contamination')
axes[1].set_ylabel('contamination')
axes[1].set_xlabel('Number of features')
axes[1].set_xticks(x)
axes[1].legend()

plt.show()

# %%
sns.scatterplot(x=data['u']-data['g'],y=data['g']-data['r'],hue=data['class'])

# predict the classification probabilities on a grid
knc = KNeighborsClassifier(10)
knc.fit(matrix_train[:,:2],classes_train)
xlim = (-2, 6)
ylim = (-11, 5)
xx, yy = np.meshgrid(np.linspace(xlim[0], xlim[1], 71),
                         np.linspace(ylim[0], ylim[1], 81))
Z = knc.predict_proba(np.c_[xx.ravel(), yy.ravel()])
Z = Z[:, 1].reshape(xx.shape)
plt.contour(xx, yy, Z, [0.5], colors='k')

plt.xlabel('u-g')
plt.ylabel('g-r')
plt.title('Dataset')
plt.show()

# %% [markdown]
# # ROC curves

# %%
gnb = GaussianNB()
gnb.fit(matrix_train[:,:2],classes_train)
scores = gnb.predict_proba(matrix_test[:,:2])[:,1]
fpr, tpr, thresholds = metrics.roc_curve(classes_test, scores)
plt.plot(fpr,tpr,label= 'GNB')

lda = LDA()
lda.fit(matrix_train[:,:1],classes_train)
scores = lda.predict_proba(matrix_test[:,:1])[:,1]
fpr, tpr, thresholds = metrics.roc_curve(classes_test, scores)
plt.plot(fpr,tpr,label= 'LDA')

qda = QDA()
qda.fit(matrix_train[:,:2],classes_train)
scores = qda.predict_proba(matrix_test[:,:2])[:,1]
fpr, tpr, thresholds = metrics.roc_curve(classes_test, scores)
plt.plot(fpr,tpr,label= 'QDA')

gmmb = GMMBayes(5)
gmmb.fit(matrix_train,classes_train)
scores = gmmb.predict_proba(matrix_test)[:,1]
fpr, tpr, thresholds = metrics.roc_curve(classes_test, scores)
plt.plot(fpr,tpr,label= 'GMMB')

knc = KNeighborsClassifier(25)
knc.fit(matrix_train,classes_train)
scores = knc.predict_proba(matrix_test)[:,1]
fpr, tpr, thresholds = metrics.roc_curve(classes_test, scores)
plt.plot(fpr,tpr,label= 'KNC')

plt.xlim(-0.001,0.04)
plt.xlabel('false positive rate')
plt.ylabel('true positive rate')
plt.title('ROC curves')
plt.legend()
plt.show()
