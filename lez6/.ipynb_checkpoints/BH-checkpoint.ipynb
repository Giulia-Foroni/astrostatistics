# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import scipy.stats
import pylab as plt
from matplotlib import pyplot as plt
from scipy import stats
import random
import math
import sklearn
from sklearn.mixture import GaussianMixture

# %%
data = np.load("formationchannels.npy")
a,b,c=plt.hist(data,100,density=True)
#plt.show()
gm = GaussianMixture(n_components=3).fit(data)
plt.plot(np.linspace(np.min(data),np.max(data),100),np.exp(gm.score_samples(np.linspace(np.min(data),np.max(data),100)[:,np.newaxis])))
plt.show()

# %%
gm.score(np.linspace(np.min(data),np.max(data),100)[:,np.newaxis])
# Out:
# -5.029480133631849
