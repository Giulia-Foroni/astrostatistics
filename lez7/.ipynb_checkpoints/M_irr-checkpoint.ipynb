# %%
import numpy as np
import scipy.stats
import pylab as plt
from matplotlib import pyplot as plt
from scipy import stats
import random
import math
import sklearn
from sklearn.mixture import GaussianMixture
from sklearn.neighbors import KernelDensity

# %%
def f(chi):
    return np.sqrt((1+np.sqrt(1-chi**2))/2)
    
def p_f(f):
    return 2*(2*f**2-1)/np.sqrt(1-f**2)

def integral(f,M,mu,sigma):
    return np.exp(-(M/f-mu)**2/(2*sigma**2))*(2*f**2-1)/(f*np.sqrt(1-f**2))

def p_M_irr(left,right,f,M,mu,sigma):
    return np.sqrt(2/np.pi)/sigma*(right-left)/N*sum(integral(f,M,mu,sigma))

def kde_sklearn(data, bandwidth, xgrid, kernel="gaussian"):
    kde_skl = KernelDensity(bandwidth = bandwidth, kernel=kernel)
    kde_skl.fit(data[:, np.newaxis])
    log_pdf = kde_skl.score_samples(xgrid[:, np.newaxis]) # sklearn returns log(density)
    return np.exp(log_pdf)

# %% [markdown]
# ## Plot the $M_{irr}$ distribution in a histogram

# %%
#I generate my distribution
mu = 1
sigma = 0.02
chi = np.random.uniform(0,1,1000)
M = np.random.normal(mu,sigma,1000)
M_irr = M*f(chi)

#bins with variable width: same number of objects in each bin
bins100 = np.append(np.sort(M_irr)[::100],np.max(M_irr))
a,b,c=plt.hist(M_irr,bins100,density=True,label='100 values in each bin',histtype="step",color='blue')
bins30 = np.append(np.sort(M_irr)[::30],np.max(M_irr))
a,b,c=plt.hist(M_irr,bins30,density=True,label='30 values in each bin',histtype="step",color='green')

plt.legend()
plt.title('$M_{irr}$ distribution')
plt.xlabel(r"$M_{irr}$ [$\mu$]")
plt.ylabel(r'p($M_{irr}$)')
plt.show()

# %% [markdown]
# ## Plot the $M_{irr}$ distribution using a KDE

# %%
x_plot = np.linspace(np.min(M_irr),np.max(M_irr),1000)

bandwidth = 0.001
y = kde_sklearn(M_irr,bandwidth,x_plot)
plt.plot(x_plot,y,label='KDE',c='red')
a,b,c=plt.hist(M_irr,bins30,density=True,label='histogram',histtype="step",color='green')
plt.title('Kernel Density Estimation')
plt.text(np.min(x_plot),np.max(y)-1,'bandwidth = '+str(bandwidth)+'\n30 values in each bin')
plt.xlabel(r"$M_{irr}$ [$\mu$]")
plt.legend()
plt.show()

bandwidth = 0.01
y = kde_sklearn(M_irr,bandwidth,x_plot)
plt.plot(x_plot,y,label='KDE',c='red')
a,b,c=plt.hist(M_irr,bins100,density=True,label='histogram',histtype="step",color='blue')
plt.title('Kernel Density Estimation')
plt.text(np.min(x_plot),np.max(y)-1,'bandwidth = '+str(bandwidth)+'\n100 values in each bin')
plt.xlabel(r"$M_{irr}$ [$\mu$]")
plt.legend()
plt.show()

#bigger number of values in each bin <==> bigger bandwidth
#smaller number of values in each bin <==> smaller bandwidth

# %% [markdown]
# ## KS distance

# %%
chi = np.random.uniform(0,1,1000)
D_KS_f = []
D_KS_M = []
sigma = np.geomspace(10**(-4),10**4,100)

for i in sigma:
    M = np.random.normal(mu,i,1000)
    M_irr = M*f(chi)
    D_KS_f.append(scipy.stats.ks_2samp(M_irr,f(chi)).statistic)
    D_KS_M.append(scipy.stats.ks_2samp(M_irr,M).statistic)
    
plt.plot(sigma,D_KS_f,'.',label=r'$M_{irr}$/$\mu$ and f')
plt.plot(sigma,D_KS_M,'.',label=r'$M_{irr}$/$\mu$ and M')
plt.title('KS distance')
plt.xscale('log')
plt.xlabel(r'$\sigma$')
plt.ylabel('D')
plt.legend()
plt.show()

# %% [markdown]
# We expect $M_{irr}$ to be distributed as $f$ for small values of $\sigma$ and to be distributed as $M$ for big values of $\sigma$

# %% [markdown]
# ## Analytic distributions of $f$ and $M_{irr}$

# %%
chi = np.random.uniform(0,1,1000)
x_plot = np.linspace(1/math.sqrt(2),0.999,1000)
plt.hist(f(chi),bins30,density=True,label='f')  #histogram
plt.plot(x_plot,p_f(x_plot),label=r'$\pi$(f)')  #analytic distribution
plt.legend()
plt.xlim(0.67,1.01)
plt.title(r'$\pi$(f)')
plt.xlabel('$f$')
plt.show()

# %%
sigma = 0.02
chi = np.random.uniform(0,1,1000)
M = np.random.normal(mu,sigma,1000)
M_irr = M*f(chi)
plt.hist(M_irr,bins30,density=True,label='$M_{irr}$')  #histogram

#for the integral I use Montecarlo: p(x) is a uniform distribution [1/sqrt(2),1]
N = 10000
left = 1/math.sqrt(2)
right = 1
x_uniform = np.random.uniform(left,right,N)
x_plot = np.linspace(np.min(M_irr),np.max(M_irr),100)
pdf = [p_M_irr(left,right,x_uniform,i,mu,sigma) for i in x_plot]
plt.plot(x_plot,pdf,label='p($M_{irr}$)')    #analytic distribution

plt.legend()
plt.title('p($M_{irr}$)')
plt.xlabel('$M_{irr}$')
plt.show()

# %% [markdown]
# ## $M_{irr}$ distribution for different values of $\sigma$

# %%
chi = np.random.uniform(0,1,1000)

sigma = 0.001
M = np.random.normal(mu,sigma,1000)
M_irr = M*f(chi)
a,b,c=plt.hist(M_irr,90,density=True,label='$M_{irr}$')
x_plot = np.linspace(np.min(M_irr),np.max(M_irr),100)
pdf = [p_M_irr(left,right,x_uniform,i,mu,sigma) for i in x_plot]
plt.plot(x_plot,pdf,label='p($M_{irr}$)')
plt.legend()
plt.xlabel('$M_{irr}$')
plt.title(r'$\sigma$  = ' + str(sigma))
plt.show()

sigma = 2
M = np.random.normal(mu,sigma,1000)
M_irr = M*f(chi)
a,b,c=plt.hist(M_irr,90,density=True,label='$M_{irr}$')
x_plot = np.linspace(np.min(M_irr),np.max(M_irr),100)
pdf = [p_M_irr(left,right,x_uniform,i,mu,sigma) for i in x_plot]
plt.plot(x_plot,pdf,label='p($M_{irr}$)')
plt.legend()
plt.xlabel('$M_{irr}$')
plt.title(r'$\sigma$  = ' + str(sigma))
plt.show()
